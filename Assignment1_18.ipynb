# %% [markdown]
# ## **Do the following operation on Iris dataset:**
#
# 1. Read the dataset to python environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('/content/iris.xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
data.mean()
# Out:
# <ipython-input-26-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
#data.describe()
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations

# %%
#1 Barplot
plt.bar(data['PL'],data['PW'])
plt.title('Petal Length VS Petal Width')
plt.ylabel('Petal Width')
plt.xlabel('Petal Length')
# Out:
# Text(0.5, 0, 'Petal Length')

# %%
#2  Scatterplot of SL vs SW
import seaborn as sns
sns.scatterplot(x='SL', y='SW',hue='Classification', data=data, )
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
#3 scatterplot of PL vs PW
sns.scatterplot(x='PL', y='PW',hue='Classification', data=data, )
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
#4 boxplot
sns.boxplot(x="Classification", y="PL", palette="husl", data=data)
# Out:
# <ipython-input-35-fcf98731d073>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Classification", y="PL", palette="husl", data=data)
# <Axes: xlabel='Classification', ylabel='PL'>

# %%
#5 boxplot
data.boxplot(by="Classification", figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'PL'}, xlabel='[Classification]'>,
#         <Axes: title={'center': 'PW'}, xlabel='[Classification]'>],
#        [<Axes: title={'center': 'SL'}, xlabel='[Classification]'>,
#         <Axes: title={'center': 'SW'}, xlabel='[Classification]'>]],
#       dtype=object)

# %%
#6 Pairplot
sns.pairplot(data)

# %%
#7 Heatmap
sns.heatmap(data.corr(), annot=True)
# Out:
# <ipython-input-41-feb2776b24b2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <Axes: >
